# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_sas("P_DEMO.XPT")

# %%
df.head()
# Out:
#        SEQN  SDDSRVYR  RIDSTATR  RIAGENDR  RIDAGEYR  RIDAGEMN  RIDRETH1  \
# 0  109263.0      66.0       2.0       1.0       2.0       NaN       5.0
# 1  109264.0      66.0       2.0       2.0      13.0       NaN       1.0
# 2  109265.0      66.0       2.0       1.0       2.0       NaN       3.0
# 3  109266.0      66.0       2.0       2.0      29.0       NaN       5.0
# 4  109267.0      66.0       1.0       2.0      21.0       NaN       2.0
#
#    RIDRETH3  RIDEXMON  DMDBORN4  ...  FIAINTRP  MIALANG  MIAPROXY  MIAINTRP  \
# 0       6.0       2.0       1.0  ...       2.0      NaN       NaN       NaN
# 1       1.0       2.0       1.0  ...       2.0      1.0       2.0       2.0
# 2       3.0       2.0       1.0  ...       2.0      NaN       NaN       NaN
# 3       6.0       2.0       2.0  ...       2.0      1.0       2.0       2.0
# 4       2.0       NaN       2.0  ...       2.0      NaN       NaN       NaN
#
#    AIALANGA      WTINTPRP      WTMECPRP  SDMVPSU  SDMVSTRA  INDFMPIR
# ...

# %% [markdown]
# ## How many people were surveyed?

# %%
# The amount of rows in the dataset. The function df.info() could also have been used here.
len(df)
# Out:
# 15560

# %% [markdown]
# ## How old was the average person surveyed?

# %%
df["RIDAGEYR"].mean()
# Out:
# 33.742480719794344

# %% [markdown]
# ## What percent of black participants in the study graduated highschool?

# %%
# Filtering

# Over 20
df_over_20 = df[df["RIDAGEYR"] >= 20]

# Over 20 and black
df_over_20_black = df_over_20[df_over_20["RIDRETH1"] == 4]

# Over 20, black and graduated high school
df_over_20_black_high = df_over_20_black[df_over_20_black["DMDEDUC2"].isin([3, 4, 5])]

# %%
len(df_over_20_black_high) / len(df_over_20_black) * 100
# Out:
# 84.26189507930053

# %% [markdown]
# ## Show the average income levels of study participants by race in a bar graph. Which group has the highest income? The lowest?

# %%
df_race_mean = df.groupby("RIDRETH3")["INDFMPIR"].mean().reset_index()

# %%
# Grouping by race and taking mean of all columns
df_race_mean = df.groupby("RIDRETH3")["INDFMPIR"].mean().reset_index()

# Creating new column with the average income by multiplying the ratio with the income at poverty line
df_race_mean["AVGINCOME"] = df_race_mean["INDFMPIR"] * 14800

# %%
df_race_mean
# Out:
#    RIDRETH3  INDFMPIR     AVGINCOME
# 0       1.0  1.944515  28778.824242
# 1       2.0  2.003089  29645.721641
# 2       3.0  2.808171  41560.930602
# 3       4.0  1.894876  28044.168850
# 4       6.0  3.229731  47800.023881
# 5       7.0  2.394256  35434.985667

# %%
df_race_mean.head()
# Out:
#                    SEQN  SDDSRVYR  RIDSTATR  RIAGENDR   RIDAGEYR   RIDAGEMN  \
# RIDRETH3
# 1.0       117131.481407      66.0  1.928643  1.510050  28.726633  10.090909
# 2.0       117064.969560      66.0  1.933290  1.511658  33.212435   9.421053
# 3.0       116981.215898      66.0  1.905900  1.497818  36.903813  10.419948
# 4.0       117079.997072      66.0  1.928258  1.506101  33.573206  11.026087
# 6.0       117060.086081      66.0  1.910256  1.526862  35.888889  12.258065
#
#           RIDRETH1  RIDEXMON  DMDBORN4   DMDYRUSZ  ...   MIALANG  MIAPROXY  \
# RIDRETH3                                           ...
# 1.0            1.0  1.309524  1.512060  11.220779  ...  1.280827  1.993585
# 2.0            2.0  1.529493  1.520725   7.836538  ...  1.329982  1.989031
# 3.0            3.0  1.570681  1.029786   4.675159  ...  1.001331  1.991749
# 4.0            4.0  1.436909  1.083455   4.484962  ...  1.000000  1.992455
# ...

# %%
df_race_mean.replace(index=
                    {1: 'Mexican American',
                     2: 'Other Hispanic',
                     3: 'Non-Hispanic White',
                     4: 'Non-Hispanic Black',
                     6: 'Non-Hispanic Asian',
                     7: 'Other Race - Including Multi-Racial'
                    }, inplace = True)

# %%
df_race_mean.head()
# Out:
#                     RIDRETH3  INDFMPIR     AVGINCOME
# 0                        1.0  1.944515  28778.824242
# Mexican American         2.0  2.003089  29645.721641
# Other Hispanic           3.0  2.808171  41560.930602
# Non-Hispanic White       4.0  1.894876  28044.168850
# Non-Hispanic Black       6.0  3.229731  47800.023881

# %%
df_race_mean.reset_index(inplace = True)

# %%
df_race_mean.head()
# Out:
#                 index  RIDRETH3  INDFMPIR     AVGINCOME
# 0                   0       1.0  1.944515  28778.824242
# 1    Mexican American       2.0  2.003089  29645.721641
# 2      Other Hispanic       3.0  2.808171  41560.930602
# 3  Non-Hispanic White       4.0  1.894876  28044.168850
# 4  Non-Hispanic Black       6.0  3.229731  47800.023881

# %%
plt.bar("", "AVGINCOME", data = df_race_mean)
# Out:
# <BarContainer object of 6 artists>

# %%
df_race_mean
# Out:
#                               RIDRETH3           SEQN  SDDSRVYR  RIDSTATR  \
# 0                     Mexican American  117131.481407      66.0  1.928643
# 1                       Other Hispanic  117064.969560      66.0  1.933290
# 2                   Non-Hispanic White  116981.215898      66.0  1.905900
# 3                   Non-Hispanic Black  117079.997072      66.0  1.928258
# 4                   Non-Hispanic Asian  117060.086081      66.0  1.910256
# 5  Other Race - Including Multi-Racial  116972.621197      66.0  1.923454
#
#    RIAGENDR   RIDAGEYR   RIDAGEMN  RIDRETH1  RIDEXMON  DMDBORN4  ...  \
# 0  1.510050  28.726633  10.090909       1.0  1.309524  1.512060  ...
# 1  1.511658  33.212435   9.421053       2.0  1.529493  1.520725  ...
# 2  1.497818  36.903813  10.419948       3.0  1.570681  1.029786  ...
# 3  1.506101  33.573206  11.026087       4.0  1.436909  1.083455  ...
# 4  1.526862  35.888889  12.258065       5.0  1.427901  1.735043  ...
# ...
